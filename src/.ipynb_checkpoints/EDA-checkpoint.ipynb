# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_daily = pd.read_csv('../data/Binance_BTCUSDT_d.csv', parse_dates=True, index_col='date')
df_daily = df_daily.drop(columns=['unix', 'symbol'])

df_daily.head()
# Out:
#                 open      high       low     close   Volume BTC   Volume USDT  \
# date
# 2022-04-01  45510.35  45644.86  45351.73  45405.33   1115.88769  5.081527e+07
# 2022-03-31  47067.99  47600.00  45200.00  45510.34  48645.12667  2.262485e+09
# 2022-03-30  47434.79  47700.22  46445.42  47067.99  40947.20850  1.932153e+09
# 2022-03-29  47122.21  48096.47  46950.85  47434.80  36772.28457  1.748600e+09
# 2022-03-28  46827.76  48189.84  46663.56  47122.21  58949.26140  2.789898e+09
#
#             tradecount
# date
# 2022-04-01     33384.0
# 2022-03-31   1290541.0
# 2022-03-30   1081607.0
# 2022-03-29   1095678.0
# 2022-03-28   1498975.0

# %%
df_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1690 entries, 2022-04-01 to 2017-08-17
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   open         1690 non-null   float64
#  1   high         1690 non-null   float64
#  2   low          1690 non-null   float64
#  3   close        1690 non-null   float64
#  4   Volume BTC   1690 non-null   float64
#  5   Volume USDT  1690 non-null   float64
#  6   tradecount   1566 non-null   float64
# dtypes: float64(7)
# memory usage: 105.6 KB

# %%
df_datahub = pd.read_csv('../data/bitcoin_csv.csv', parse_dates=True, index_col='date', usecols=['date', 'price(USD)'])
df_datahub.head()
# Out:
#             price(USD)
# date
# 2009-01-09         NaN
# 2009-01-10         NaN
# 2009-01-11         NaN
# 2009-01-12         NaN
# 2009-01-13         NaN

# %%
df_datahub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3605 entries, 2009-01-09 to 2018-11-22
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   price(USD)  2035 non-null   float64
# dtypes: float64(1)
# memory usage: 56.3 KB

# %%
df_datahub.tail()
# Out:
#             price(USD)
# date
# 2018-11-18     5559.74
# 2018-11-19     5620.78
# 2018-11-20     4863.93
# 2018-11-21     4465.54
# 2018-11-22     4611.57

# %%
df_daily.loc['2018-11', ['open', 'high', 'low', 'close']]
# Out:
#                open     high      low    close
# date
# 2018-11-30  4295.72  4341.36  3943.00  4041.32
# 2018-11-29  4262.06  4450.38  4125.65  4295.84
# 2018-11-28  3875.63  4394.47  3874.27  4264.85
# 2018-11-27  3864.45  3940.00  3689.12  3875.21
# 2018-11-26  4088.69  4206.00  3701.00  3862.20
# 2018-11-25  3933.68  4233.00  3652.66  4085.78
# 2018-11-24  4415.63  4527.00  3824.69  3932.44
# 2018-11-23  4370.90  4484.00  4222.94  4420.61
# 2018-11-22  4661.08  4721.77  4335.00  4370.00
# 2018-11-21  4559.91  4787.20  4413.85  4661.07
# 2018-11-20  4913.40  5048.24  4326.00  4558.86
# 2018-11-19  5661.94  5664.00  4855.00  4910.03
# 2018-11-18  5630.49  5738.17  5617.00  5662.00
# 2018-11-17  5650.57  5656.60  5565.43  5628.29
# 2018-11-16  5757.09  5782.89  5549.25  5655.94
# 2018-11-15  5917.20  5939.54  5403.42  5753.40
# 2018-11-14  6458.98  6482.84  5656.87  5922.41
# 2018-11-13  6451.68  6498.00  6391.15  6457.66
# 2018-11-12  6450.71  6497.00  6421.00  6453.07
# ...

# %%
df_datahub.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_daily['open'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_datahub.plot()
df_daily['open'].plot()
# Out:
# <AxesSubplot:xlabel='date'>
